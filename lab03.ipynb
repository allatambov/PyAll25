# %% [markdown]
# ## Лабораторная работа №3: цикл `while`
#
# Для выполнения этой работы необходимо:
#
# * понимать устройство цикла `while`;
# * понимать устройство конструкции цикл `for` + оператор `break`.
#
# С необходимыми материалами можно ознакомиться на странице курса или в теме 3 онлайн-курса «Python как иностранный» (эта тема онлайн-курса стоит до цикла `for`, про цикл `for` + `break` удобнее посмотреть в конспекте на странице).
#
# **За разные задачи можно получить разное число баллов. Чтобы получить оценку 10, необходимо корректно выполнить все задачи и выполнить бонусный пункт в №1 (без него максимальная оценка – 9).**
#
# Задача считается решенной, если код успешно проходит автоматические тесты и не содержит грубых нарушений («подгонка» под тесты, копирование кода другого студента). «Подгонка» под тесты – написание кода не для общего случая, а для соответствия конкретным значениям в ячейке с тестами. Пример: пишем не универсальный код для проверки четности числа, а код, который правильно работает только на числах 2, 5, 8, потому что именно эти числа используются в `test_data` .

# %% [markdown]
# ### Формат сдачи
#
# Для сдачи лабораторной работы необходимо скачать текущий ipynb-файл, вписать в него свои решения, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере.
#
# Получить ipynb-файл можно, выбрав в Jupyter пункт меню *File → Download as... → Notebook (.ipynb)*.

# %% [markdown]
# ### Тесты для проверки кода
#
# На первом этапе проверки ваши решения в домашних заданиях и лабораторных работах будут проверяться с помощью автоматических тестов – ячеек с кодом, которые проверяют соответствие результатов исполнения ваших программ ожидаемым результатам в условиях задач. Эти тесты можно использовать для проверки кода перед сдачей задания.
#
# Итак, для предварительной проверки задания нужно сделать следующее:
#
# 1. Скачать данный ipynb-файл на свой компьютер, открыть его в Jupyter Notebook.
# 2. Активировать тесты (см. ниже).
# 3. Вставить решение каждой задачи в ячейку для кода, следующую за его условием, там, где написан комментарий `# YOUR CODE HERE`. Отступ вашего кода должен составлять 4 пробела. Ничего не менять вокруг!
# 4. Запустить ячейку, в которую вы вставили код с решением. Ввести какие-то входные данные, проверить визуально правильность вывода.
# 5. Запустить следующую ячейку (в ней содержится тест). Если запуск ячейки с тестом не приводит к появлению ошибки (`assertion`), значит, всё в порядке, задача решена. Если приводит к появлению ошибки, значит, тест не пройден и нужно искать ошибку.
#
# Внимание! Если в какой-то момент забыть ввести входные данные и перейти на следующую ячейку, есть риск, что Notebook перестанет откликаться. В этом случае надо перезапустить ядро: *Kernel → Restart*. При этом потеряются все значения переменных, но сам код останется.

# %% [markdown]
# ### Активировать тесты
#
# Запустите следующую ячейку, чтобы иметь возможность запускать тесты.

# %%
# Фабрика тестов для проверки программ, принимающих данные через input()
# Автор тестов: И.В.Щуров

from collections import deque

class Tester(object):
    def __init__(self, inp):
        self.outputs = []
        self.inputs = deque(inp)
    def print(self, *args, sep = " ", end = "\n"):
        text = sep.join(map(str, args)) + end
        newlines = text.splitlines(keepends=True)
        if self.outputs and self.outputs[-1] and self.outputs[-1][-1] != "\n" and newlines:
            self.outputs[-1] += newlines[0]
            self.outputs.extend(newlines[1:])
        else:
            self.outputs.extend(newlines)
            
    def input(self, *args):
        assert self.inputs, "Вы пытаетесь считать больше элементов, чем предусмотрено условием"
        return self.inputs.popleft()
    def __enter__(self):
        global print
        global input
        print = self.print
        input = self.input
        return self.outputs
    def __exit__(self, *args):
        global print
        global input
        del print
        del input

# %% [markdown]
# ### Задача 1. 38 попугаев (1 балл)
#
# Удав не может уснуть и пытается считать попугаев перед сном (овцы в тех широтах не водятся). У него богатое воображение, поэтому попугаи в его фантазиях пролетают не только по одному, но и маленькими стайками. Он точно знает, что если попугаев будет не меньше 38, он уснет.
#
# Напишите программу, которая запрашивает с клавиатуры количество пролетающих попугаев до тех пор, пока их не станет 38 или больше. Как только нужное количество попугаев набирается, выводится сообщение вида `Пролетело n попугаев. Удав заснул!`, где `n` – посчитанное число попугаев.
#
# Согласование числительного в `n` с формой существительного *попугаев* можно игнорировать, то есть фразы вида `Пролетело 22 попугаев. Удав заснул!` считаются корректными, в тестах нет примеров с изменением грамматики.
#
# **Бонусный балл (+1).** Предложите более общее решение, где в зависимости от числительного выбирается подходящая форма существительного (*попугаев*, *попугая*, *попугай*) и глагола (*пролетело*, *пролетел*). Это возможно сделать без использования специальных библиотек.
#
# **Пример работы программы:**
#
# Ввод:
#
#     2
#     1
#     1
#     10
#     6
#     2
#     4
#     8
#     4
#
# Вывод:
#
#     Пролетело 38 попугаев. Удав заснул!
#
#
# Ввод:
#
#     10
#     10
#     8
#     4
#     7
#
# Вывод:
#
#     Пролетело 39 попугаев. Удав заснул!
#
#
#
# Ввод:
#
#     10
#     15
#     10
#     10
#
# Вывод:
#
#     Пролетело 45 попугаев. Удав заснул!

# %%
def parrots_count():
    
    # YOUR CODE HERE
    
parrots_count()

# %%
test_data = [("2,1,1,10,6,2,4,8,4",["Пролетело 38 попугаев. Удав заснул!"]),
             ("10,15,10,10", ["Пролетело 45 попугаев. Удав заснул!"]),
             ("10,10,8,4,7", ["Пролетело 39 попугаев. Удав заснул!"]),
             ("1,5,4,8,22", ["Пролетело 40 попугаев. Удав заснул!"]),
             ("100", ["Пролетело 100 попугаев. Удав заснул!"])]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        parrots_count()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ### Задача 2. Painting in Wonderland (1 балл)
#
# Соня на Безумном чаепитии у Шляпника рассказывала о сестрах, которые жили в колодце и рисовали всё, что начинается на букву М. Будем считать, что если им попадается предмет на другую букву, они прекращают рисовать и больше ничего не рисуют в этот день.
#
# Напишите программу, которая считает количество рисунков, сделанных за день сестрами, то есть программу, которая:
#
# * запрашивает с клавиатуры слова (один ввод = одно слово) до тех пор, пока не встретит слово, начинающее не на *М* (заглавная *М* и строчная *м*);
#
# * выводит на экран итоговое число рисунков, то есть количество слов на букву *М* и *м*, введенных пользователем.
#
# **Пример работы программы:**
#
# Ввод:
#
#     мышь
#     мантия
#     множество
#     Мантикора
#     солнце
#
#
# Вывод:
#
#     4
#
#
# Ввод:
#
#     мышеловка
#     миллионер
#     МАСКА
#     Микрокосм
#     мигрень
#     апельсин
#
# Вывод:
#
#     5
#
# Ввод:
#
#     луна
#
# Вывод:
#
#     0

# %%
def image_count():
    
    # YOUR CODE HERE
    
    
image_count()

# %%
test_data = [("мыло,метель,микроскоп,стоп",["3"]),
             ("мышь,мастерок,Марс,МАНТИЯ,апельсин", ["4"]),
             ("моль,МОГИКАНЕ,мольберт,Мурка,мороженое,стакан", ["5"]),
             ("микрокосм,мигрень,кот", "2"),
             ("луна", "0")]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        image_count()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ### Задача 3. Expecto problema (2 балла)
#
# У профессора Снейпа на этой неделе очень плохое настроение, поэтому он не успокоится, пока в списке студентов, проваливших тест, не окажется Гарри Поттера. Ради этого он готов провести сколько угодно тестов.
#
# Реализуйте программу, которая считает количество тестов, написанных студентами.
#
# * Задан пустой список `who_failed`. Этот код уже написан.
# * В цикле считываются строки с перечнем фамилий студентов через пробел до тех пор, пока в перечне не окажется фамилии `Potter`. Гарантируется, что до строки с `Potter` будет введена как минимум одна строка с перечнем фамилий.
# * Каждую введенную фамилию добавляйте в список `who_failed`.
# * Напечатайте число написанных тестов.
#
# **Примеры работы программы:**
#
# Ввод:
#
#     Weasley Longbottom Bell
#     Crabbe Spinnet
#     Brown Potter
#
# Результат:
#
#     3
#
# Ввод:
#
#     Longbottom Bell
#     Crabbe Weasley Weasley
#     Spinnet Brown
#     Potter Weasley
#
# Результат:
#
#     4

# %%
def expecto_problema():
    
    who_failed = []
    students = input().split()
    
    # YOUR CODE HERE
    
expecto_problema()

# %%
test_data = [("Longbottom Bell,Crabbe Weasley Weasley,Spinnet Brown,Potter Weasley",
              ["4"]),
             ("Weasley Longbottom Bell,Crabbe Spinnet,Brown Potter", ["3"]),
             ("A,B,C,D,E,Potter", ["6"])
             ]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        expecto_problema()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ### Задача 4. Два озера – твои глаза (2 балла)
#
# Одним прекрасным летним вечером Питон решил спеть для Анаконды песню. Он попросил своего друга подыграть ему на гитаре и запел. Всё шло хорошо, но в середине Питон понял, что в песне есть слова «И я на цыпочки привстал», задумался, как пресмыкающиеся встают на цыпочки, смутился и перестал петь (но Анаконда всё равно была в восторге).
#
# Строки песни сохранены в список `song`, один элемент списка соответствует одной строке песни. Код для считывания строк из файла, размещённого на Github, уже написан, у всех должен работать при наличии подключения к Интернету.
#
# Напишите программу, которая реализует описанную выше ситуацию: выводит на экран строки песни до тех пор, пока не натолкнется на строку, содержащую выражение «на цыпочки». Итоговая выдача должна выглядеть так (с многоточием в конце, это «заминка»):
#
#     Идет по свету менестрель, поет не "тра-ля-ля",
#     Он песню бережно несет про дочку короля,
#     За что бродячий менестрель ей стал однажды люб,
#     Пускай узнает вся земля, узнает добрый люд.
#     Вот перед ней, вот перед ней, вот перед ней
#     Какую трель рассыпал менестрель.
#     Два озера - твои глаза, я в них окончу путь,
#     Я просто выбрать не могу, в каком мне утонуть,
#     Я просто выбрать не могу, и я покуда жив,
#     Но я, как в песне соловей, перед тобой не лжив.
#     Вот перед ней, вот перед ней, вот перед ней
#     Какую трель рассыпал менестрель.
#     И руки нежные твои струятся, как ручьи,
#     Они текут, творя добро, они пока ничьи,
#     Манят пришельца два ручья, чтоб он напился всласть
#     Я только выбрать не могу, к которому припасть.
#     Вот перед ней, вот перед ней, вот перед ней
#     Какую трель рассыпал менестрель.
#     Твои глаза, твои глаза - высоких два окна,
#     И люди говорят, что в них любовь ко мне видна,
#     И я на цыпочки привстал, чтоб выше стать чуть-чуть,
#     ...
#
#
# **Важно.** Тесты ниже проверяют только соответствие вашей выдачи ожидаемому результату. Не забывайте, что код после автоматической проверки повторно проверяется вручную, поэтому учитывайте следующее: при решении нельзя использовать готовые индексы элементов списка, то есть вручную найти номер строки, содержащей «на цыпочки», и просто вывести на экран элементы до неё. Необходимо общее решение в предположении, что список строк может выглядеть иначе, например, содержать ещё какие-то строки в самом начале.

# %%
import requests
page = requests.get("https://raw.githubusercontent.com/allatambov/PyAll25/main/song.txt")
song = page.text.splitlines()

# %%
def sing_song():
    
    # YOUR CODE HERE

sing_song()

# %%
test_data = [("", ['Идет по свету менестрель, поет не "тра-ля-ля",\n',
 'Он песню бережно несет про дочку короля,\n',
 'За что бродячий менестрель ей стал однажды люб,\n',
 'Пускай узнает вся земля, узнает добрый люд.\n',
 'Вот перед ней, вот перед ней, вот перед ней\n',
 'Какую трель рассыпал менестрель.\n',
 'Два озера - твои глаза, я в них окончу путь,\n',
 'Я просто выбрать не могу, в каком мне утонуть,\n',
 'Я просто выбрать не могу, и я покуда жив,\n',
 'Но я, как в песне соловей, перед тобой не лжив.\n',
 'Вот перед ней, вот перед ней, вот перед ней\n',
 'Какую трель рассыпал менестрель.\n',
 'И руки нежные твои струятся, как ручьи,\n',
 'Они текут, творя добро, они пока ничьи,\n',
 'Манят пришельца два ручья, чтоб он напился всласть\n',
 'Я только выбрать не могу, к которому припасть.\n',
 'Вот перед ней, вот перед ней, вот перед ней\n',
 'Какую трель рассыпал менестрель.\n',
 'Твои глаза, твои глаза - высоких два окна,\n',
 'И люди говорят, что в них любовь ко мне видна,\n',
 'И я на цыпочки привстал, чтоб выше стать чуть-чуть,\n',
                   '...\n'])]

for inp, out in test_data:
    with Tester([inp]) as t:
        sing_song()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверное количество строк в выводе"
        assert line_t == "".join(out), "Неверные строки"

# %% [markdown]
# ### Задача 5. Duck Tales (3 балла)
#
# В списке `quotes` сохранены цитаты героев «Утиных историй».

# %%
quotes = [("Скрудж", "Ничего страшнее я в жизни не видел – пустой банк без денег."),
          ("Скрудж", "Грабители! Воры! Политики!"),
          ("Скрудж", "Если авария неизбежна, то пусть она будет хотя бы красивой."), 
          ("Зигзаг", "Были бы крылья, а разбиться сумеем."),
          ("Зигзаг", "Не волнуйтесь, ребята, все мечтают, чтобы я потерялся, но я всегда возвращаюсь!"),
          ("Зигзаг", "Я обязательно должен разбить его... то есть, я хотел сказать, полетать на нём!"),
          ("Зигзаг", "Катастрофа, которую можно избежать — приятная катастрофа."),
          ("Зигзаг", "Две головы лучше, чем ни одной."),
          ("Клювдия", "Что лучше: богатый селезень или мертвый?"),
          ("Клювдия", "На моей кухне я привидений не потерплю!")]

# %% [markdown]
# Напишите программу, которая реализует игру: случайным образом выбирает из списка цитату, выводит на экран цитату, просит пользователя угадать имя героя и считает количество верных ответов.
#
# Детали:
#
# * Если ответ верный, число набранных очков увеличивается на 1, пользователю предлагается следующая цитата.
# * Если ответ неверный, число набранных очков не изменяется, пользователю предлагается следующая цитата.
# * При этом уже предложенные цитаты повторно на экран не выводятся, вне зависимости от того, верно или неверно был указан ее автор.
# * Игра останавливается в двух случаях: 1) все цитаты из списка были показаны на экране; 2) пользователь ввел слово `STOP` в разных вариантах (`Stop`, `stop`, `STOP`).
# * По итогам игры на экран выводится сообщение вида `Ваш результат: n/10.`, где `n` – количество набранных очков.
#
# Ниже приведен код для случайного (псевдослучайного) выбора целого числа `k`, которое может служить индексом пары в `quotes`, а также вводная строка `intro` с пояснениями для пользователя. Обязательно используйте их в своем решении.
#
# *Автоматического теста у этой задачи нет, за нее можно получить частичный балл в зависимости от степени выполнения задания.*
#
#
# **Пример 1: пользователю показаны все цитаты**
#
#     Угадайте героя «Утиных историй» по цитате.
#     Впишите одно из имён: Скрудж, Зигзаг, Клювдия.
#
#     Две головы лучше, чем ни одной.
#     Зигзаг
#     Я обязательно должен разбить его... то есть, я хотел сказать, полетать на нём!
#     Зигзаг
#     Катастрофа, которую можно избежать — приятная катастрофа.
#     Зигзаг
#     Грабители! Воры! Политики!
#     Скрудж
#     Если авария неизбежна, то пусть она будет хотя бы красивой.
#     Скрудж
#     Были бы крылья, а разбиться сумеем.
#     Зигзаг
#     На моей кухне я привидений не потерплю!
#     Клювдия
#     Ничего страшнее я в жизни не видел – пустой банк без денег.
#     Клювдия
#     Не волнуйтесь, ребята, все мечтают, чтобы я потерялся, но я всегда возвращаюсь!
#     Зигзаг
#     Что лучше: богатый селезень или мертвый?
#     Скрудж
#     Ваш результат: 8/10.
#
# **Пример 2: пользователь остановил игру**
#
#     Угадайте героя «Утиных историй» по цитате.
#     Впишите одно из имён: Скрудж, Зигзаг, Клювдия.
#
#     Были бы крылья, а разбиться сумеем.
#     Зигзаг
#     Грабители! Воры! Политики!
#     Скрудж
#     Катастрофа, которую можно избежать — приятная катастрофа.
#     STOP
#     Ваш результат: 2/10.
#
# **Пример 3: пользователь остановил игру**
#
#     Угадайте героя «Утиных историй» по цитате.
#     Впишите одно из имён: Скрудж, Зигзаг, Клювдия.
#
#     Катастрофа, которую можно избежать — приятная катастрофа.
#     Скрудж
#     Ничего страшнее я в жизни не видел – пустой банк без денег.
#     Скрудж
#     Если авария неизбежна, то пусть она будет хотя бы красивой.
#     Скрудж
#     Были бы крылья, а разбиться сумеем.
#     Зигзаг
#     Не волнуйтесь, ребята, все мечтают, чтобы я потерялся, но я всегда возвращаюсь!
#     stop
#     Your score is 3/10.

# %%
from random import randrange

intro = """
Угадайте героя «Утиных историй» по цитате.
Впишите одно из имён: Скрудж, Зигзаг, Клювдия.
"""

# k – случайно выбранное число от 0 до 9 включительно,
# то есть номер случайно выбранной пары

k = randrange(0, len(quotes))

# YOUR CODE HERE

# %% [markdown]
# *Названия и сюжеты задач:*
#
# *№1: 38 попугаев (Союзмультфильм, 1976).*<br>
# *№2: Л.Кэрролл. Алиса в Стране чудес.*<br>
# *№3: Дж.Роулинг. Гарри Поттер и узник Азкабана.* <br>
# *№4: Песня о влюбленном менестреле, слова В.Коростылева, музыка М.Таривердиева, фильм «Ученик лекаря».*<br>
# *№5: Утиные истории (Дисней, 1987–1990)<br>*
