# %% [markdown]
# # Программирование для всех<br>(основы работы с Python)
#
# *Разработчик формата сдачи заданий и фабрики автоматических тестов: Щуров И.В.<br>
# Автор задач: Тамбовцева А.А.*

# %% [markdown]
# ### Активировать тесты
#
# Запустите следующую ячейку, чтобы иметь возможность запускать тесты в некоторых задачах.

# %%
# Фабрика тестов для проверки программ, принимающих данные через input()

from collections import deque

class Tester(object):
    def __init__(self, inp):
        self.outputs = []
        self.inputs = deque(inp)
    def print(self, *args, sep = " ", end = "\n"):
        text = sep.join(map(str, args)) + end
        newlines = text.splitlines(keepends=True)
        if self.outputs and self.outputs[-1] and self.outputs[-1][-1] != "\n" and newlines:
            self.outputs[-1] += newlines[0]
            self.outputs.extend(newlines[1:])
        else:
            self.outputs.extend(newlines)
            
    def input(self, *args):
        assert self.inputs, "Вы пытаетесь считать больше элементов, чем предусмотрено условием"
        return self.inputs.popleft()
    def __enter__(self):
        global print
        global input
        print = self.print
        input = self.input
        return self.outputs
    def __exit__(self, *args):
        global print
        global input
        del print
        del input

# %% [markdown]
# ## Часть 1: кортежи, функция `zip()` и сортировка

# %% [markdown]
# ### Задача 1
#
# В списке `data` хранятся данные по участникам медицинского исследования – id участника, вес на начало диеты, вес на конец диеты:

# %%
data = [("id56", 78, 75), 
        ("id23", 85, 85), 
        ("id12", 90, 84), 
        ("id10", 77, 79), 
        ("id99", 86, 84),
        ("id77", 72, 72),
        ("id43", 92, 86), 
        ("id48", 98, 94),
        ("id90", 89, 87),
        ("id13", 76, 71)]

# %% [markdown]
# a. Создайте список `loss`, содержащий информацию по тем же участникам в виде пар *id – количество сброшенных килограммов*, отсортированный по возрастанию сброшенных килограммов. Если человек набрал вес в ходе диеты, то количество сброшенных килограммов будет отрицательным, это нормально.
#
# **Подсказка:** сортировку выполняйте в конце, сначала просто получите необходимый набор пар.
#
# Список `loss` на выходе:
#
#     [('id10', -2), ('id23', 0), ('id77', 0), ('id99', 2), ('id90', 2),
#      ('id56', 3), ('id48', 4), ('id13', 5), ('id12', 6), ('id43', 6)]
#
# b. Используя только исходный список `data`, сохраните в список `success` с id тех, участников, чей вес после диеты оказался ниже, чем до.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Напишите программу, которая запрашивает с клавиатуры:
#
# * координаты точек по оси `x` через пробел (целые или дробные числа, могут быть отрицательными);
# * координаты точек по оси `y` через пробел (целые или дробные числа, могут быть отрицательными);
#
# и выводит на экран список, состоящий из кортежей с координатами тех точек, которые находятся внутри окружности радиуса 4 с центром в нуле, упорядоченных *от самой нижней точки к самой верхней*. Если таких точек нет, то на экран выводится пустой список.
#
# При этом, если число координат по оси `x` и `y`, выводится сообщение `"Проверьте количество элементов."`.
#
#
# **Пример работы программы:**
#
# Ввод:
#
#     0 1 4
#     1 0 0.5
#
# Вывод:
#
#     [(1.0, 0.0), (0.0, 1.0)]
#
# Ввод:
#
#     2.5 -1 0 0.8 1.5
#     3 1 0 2.8 -0.5
#
# Вывод:
#
#     [(1.5, -0.5), (0.0, 0.0), (-1.0, 1.0)]
#
# Ввод:
#
#     2 0 3
#     1 1
#
# Вывод:
#
#     Проверьте количество элементов.
#
# Иллюстрация для понимания – точка с координатами (3, 2) находится за пределами окружности, точка с координатами (2, 0) – ровно на окружности, еще две точки – внутри окружности. Вот эти две точки и должны войти в наш список.
#
# <img src="https://raw.githubusercontent.com/allatambov/PyAll25/master/circle.png" width="50%">

# %%
### YOUR CODE HERE ###

# %%
def circle():
    
    ### YOUR CODE HERE ###
    
circle()

# %%
test_data = [
    ("0 1 4;1 0 0.5;", "[(1.0, 0.0), (0.0, 1.0)]"),
    ("2.5 -1 0 0.8 1.5;3 1 0 2.8 -0.5", "[(1.5, -0.5), (0.0, 0.0), (-1.0, 1.0)]"), 
    ("1 0 1.5 2;0 -1 2 0.5", "[(0.0, -1.0), (1.0, 0.0)]"),
    ("1 -1 0 4;2 0 4", "Проверьте количество элементов."),
    ("4 5 6 7 8;0 1 2 3 4", "[]")
]

for inp, out in test_data:
    with Tester(inp.split(";")) as t:
        circle()
        assert len(t) == 1, "Вам нужно вывести ровно одну строку с ответом"
        assert t[0] == out+"\n", "Неверный ответ, была введена строка " + inp

# %% [markdown]
# ### Задача 3
#
# Напишите программу, которая фильтрует героев на основе их места проживания:
#
# * В переменную `heroes` считывается список, где хранятся имена героев через запятую без пробела (строки).
# * В переменную `places` считывается список, где хранятся места проживания героев через запятую без пробела (строки). Каждый год соответствует студенту из списка `heroes`.
# * Гарантируется, что будет введена информация минимум для одного героя.
# * В переменную `place` считывается строка — место проживания, который нас интересует.
# * Программа выводит имена героев, которые проживают в месте, указанном в `place`, каждое на новой строке.
# * Если таких героев нет, то программа ничего не выводит.
#
# **Примеры работы программы:**
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Мама
#     Лес, Москва, Париж, Москва
#     Москва
#
# Результат:
#
#     Красная Шапочка
#     Мама
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Айболит
#     Лес, Москва, Париж, Лес
#     Лес
#
# Результат:
#
#     Волк
#     Айболит
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Айболит
#     Лес, Москва, Париж, Лес
#     Лондон
#
# Результат:
#
#     [ничего не выводится]

# %%
def tale():
    
    ### YOUR CODE HERE ###
    
tale()

# %%
test_data = [
    ("Волк, Красная Шапочка, Бабушка, Айболит;Лес, Москва, Париж, Лес;Лес", 
     ["Волк", "Айболит"]),
    ("Волк, Красная Шапочка, Бабушка, Мама;Лес, Москва, Париж, Москва;Москва", 
     ["Красная Шапочка", "Мама"]),
    ("Волк, Красная Шапочка, Бабушка, Айболит;Лес, Москва, Париж, Лес;Лондон", 
     [])
]

for inp, out in test_data:
    with Tester(inp.split(";")) as t:
        tale()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ## Часть 2: словари

# %% [markdown]
# ### Задача 1
#
# Дан словарь с названиями разных рептилий:

# %%
rept = {"python" : " питон", 
        "anaconda" : "анаконда", 
        "tortoize" : " черепаха" }

# %% [markdown]
# * Добавьте в словарь пару "snake" – " змея".
# * Исправьте ключ "tortoize" на правильный "tortoise".
# * Для всех слов в словаре выведите на экран сообщения вида `Питон по-английски будет python.`

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# В списке `cnt` хранятся названия стран, а в списке `fh` – значения индекса Freedom House для этих стран. Создайте словарь, используя в качестве ключей названия стран, а в качестве значений – значения индекса.

# %%
cnt = ["Andorra", "Belarus", "Denmark", 
       "Kenya", "Jamaica", "Romania"]
fh = [1.0, 6.0, 1.0, 4.0, 2.5, 2.0]

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Дан словарь `grades` с оценками студентов за контрольную работу в 5-балльной шкале. Напишите код, который сделает следующее:
#
# * Выведет на экран имя каждого студента и его оценку (каждый студент – с новой строки).
# * Сохранит имена студентов, получивших отличные оценки, в список `excel`.
# * Сохранит имена студентов, получивших хорошие оценки, в список `good`.
# * Сохранит имена студентов, получивших удовлетворительные оценки, в список `satisf`.
# * Сохранит имена студентов, получивших плохие оценки, в список `bad`.

# %%
grades = {'Anna': 4, 'Bob': 3, 'Claire': 5, 'Dick': 2, 'Elena': 5, 
         'Fred': 5, 'George': 4, 'Kristina': 3, 'Nick': 2, 
         'Ursula': 4, 'Viktor': 5}

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4
#
# Дан список, состоящий из пар чисел:
#
#     pairs = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]
#
# Создайте словарь `calc`, где ключами являются пары чисел, а значениями – их произведение (произведение тоже должно считаться в Python, не в уме).

# %%
pairs = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]

### YOUR CODE HERE ###
